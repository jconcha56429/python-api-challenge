# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# # Observable Trends
# # 1. The closer to the equator the latitude is, the hotter the temperature and the further away, the colder the max temperature
# # 2. The closer to the equator the latitude, the lesser the wind speed (mph) and the less cloudy it is
# # 3. There is a positive relationship between latitude and humidity, the more south the latitude the less the humidity and the more north the latitude, the more the humidity

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import csv
# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
with open(output_data_file,'r') as file:
        reader = csv.reader(file)
        for row in reader:
            print(row)
print(type(reader))
# Out:
# ['City_ID', 'City', 'Cloudiness', 'Country', 'Date', 'Humidity', 'Lat', 'Lng', 'Max Temp', 'Wind Speed']
# ['0', 'ostrovnoy', '2', 'RU', '1558378754', '72', '68.05', '39.51', '37.5', '7.16']
# ['1', 'mahebourg', '75', 'MU', '1558378503', '74', '-20.41', '57.7', '78.8', '11.41']
# ['2', 'qaanaaq', '25', 'GL', '1558378755', '73', '77.48', '-69.36', '22.2', '2.37']
# ['3', 'zhuhai', '0', 'CN', '1558378755', '39', '40.71', '112.04', '44.6', '4.47']
# ['4', 'cape town', '20', 'ZA', '1558378755', '76', '-33.93', '18.42', '55.99', '8.05']
# ['5', 'atuona', '78', 'PF', '1558378755', '76', '-9.8', '-139.03', '81.96', '16.49']
# ['6', 'flinders', '0', 'AU', '1558378755', '62', '-34.58', '150.85', '60.01', '11.41']
# ['7', 'opuwo', '0', 'NA', '1558378523', '23', '-18.06', '13.84', '72.06', '5.44']
# ['8', 'tiksi', '95', 'RU', '1558378756', '88', '71.64', '128.87', '14.1', '15.7']
# ['9', 'pushkinskiye gory', '6', 'RU', '1558378756', '70', '57.02', '28.91', '65.04', '6.93']
# ...

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    # what is .city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 639

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = 'imperial'
query_url = f"{url}appid={weather_api_key}&units={units}&q="

city_data = []
names =[]
lat = []
lng = []
temp = []
max_t = []
cloud = []
wspeed = []
country = []
date = []
humid = []
record_count = 0

# %%
for city in cities:
    response = requests.get(query_url + city).json()
    try: 
        names.append(response['name']) 
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp']) 
        max_t.append(response['main']['temp_max'])
        cloud.append(response['clouds']['all']) 
        wspeed.append(response['wind']['speed']) 
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humid.append(response['main']['humidity'])
        city_data = ({'City':names,
                     'Lat':lat,
                     'Lon':lng,
                     'Temp':temp,
                     'Max Temp':max_t, 
                     'Cloudiness':cloud,
                     'Wind Speed':wspeed,
                     'Country':country,
                     'Date':date,
                     'Humidity':humid})
        print(f'city number {record_count} {city}')
        record_count += 1
    except: 
        print('uh oh city not found!')
# Out:
# city number 0 chuy
# city number 1 bertoua
# uh oh city not found!
# city number 2 esmeraldas
# city number 3 yola
# city number 4 thunder bay
# city number 5 savelugu
# uh oh city not found!
# city number 6 tuy hoa
# city number 7 hilo
# city number 8 moussoro
# city number 9 provideniya
# city number 10 jamestown
# city number 11 georgetown
# city number 12 port alfred
# city number 13 lebu
# city number 14 nola
# city number 15 vaini
# uh oh city not found!
# city number 16 bambous virieux
# city number 17 kampot
# city number 18 torbay
# city number 19 ayr
# city number 20 bethel
# city number 21 kruisfontein
# city number 22 samarai
# city number 23 busselton
# city number 24 acapulco
# city number 25 atuona
# city number 26 vostok
# uh oh city not found!
# city number 27 avarua
# city number 28 saint anthony
# city number 29 ribeira grande
# city number 30 sioux lookout
# city number 31 punta arenas
# city number 32 ilulissat
# city number 33 rikitea
# city number 34 merrill
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df = pd.DataFrame(city_data)
csv_file = df.to_csv('city_data.csv')
df.head()
# Out:
#           City      Lat      Lon   Temp  Max Temp  Cloudiness  Wind Speed  \
# 0         Chui -33.6971 -53.4616  52.11     52.11           0        7.36
# 1      Bertoua   4.5833  13.6833  67.89     67.89          65        2.62
# 2   Esmeraldas -19.7625 -44.3139  69.80     69.80           0        2.30
# 3         Yola   9.2000  12.4833  83.53     83.53         100        5.97
# 4  Thunder Bay  48.4001 -89.3168  35.42     35.60          90        8.05
#
#   Country        Date  Humidity
# 0      UY  1619500879        85
# 1      CM  1619500880        92
# 2      BR  1619500880        73
# 3      NG  1619500881        51
# 4      CA  1619500807        93

# %%
response
# Out:
# {'coord': {'lon': 54.6029, 'lat': 57.6713},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 43.68,
#   'feels_like': 37.36,
#   'temp_min': 43.68,
#   'temp_max': 43.68,
#   'pressure': 1011,
#   'humidity': 58,
#   'sea_level': 1011,
#   'grnd_level': 993},
#  'visibility': 10000,
#  'wind': {'speed': 12.33, 'deg': 254, 'gust': 19.22},
#  'clouds': {'all': 15},
#  'dt': 1619501103,
#  'sys': {'country': 'RU', 'sunrise': 1619484022, 'sunset': 1619539069},
#  'timezone': 18000,
#  'id': 574620,
#  'name': 'Bolshaya Sosnova',
#  'cod': 200}

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
df.loc[df['Humidity']>=100]
# Out:
#                        City      Lat      Lon   Temp  Max Temp  Cloudiness  \
# 18                   Torbay  47.6666 -52.7314  41.29     45.00          90
# 38                Cape Town -33.9258  18.4232  60.10     61.00          90
# 84                     Nuuk  64.1835 -51.7216  33.40     33.80          90
# 102           Mar del Plata -38.0023 -57.5575  53.08     55.99          75
# 206             Clyde River  70.4692 -68.5914  24.80     24.80          90
# 212                   Arosa  46.7779   9.6762  40.17     44.01          90
# 229            General Roca -39.0333 -67.5833  50.00     50.00           0
# 237                Cabedelo  -6.9811 -34.8339  73.40     73.40          20
# 276                   Ancud -41.8697 -73.8203  52.81     55.99          90
# 277                La Rioja  42.2500  -2.5000  52.95     54.00          75
# 370                Lichinga -13.3128  35.2406  64.20     64.40          90
# ...

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(lat,temp)
plt.title('Latitude vs. Temperature Plot (4/25/2021)')
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.savefig('weather_images/latitude_vs_temp_plt')
plt.show()

# %% [markdown]
# # This plot displays the positive correlation between latitudes closeness to the equator and the increasing temperature

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(lat,humid)
plt.title('Latitude vs. Humidity (4/25/2021)')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.savefig('weather_images/latitude_vs_humidity')
plt.show()

# %% [markdown]
# # This plot displays how there isn't really much of a correlation between latitude and humidity

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(lat,cloud)
plt.title('Latitude vs. Cloudiness (4/25/2021)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.savefig('weather_images/latitude_vs_cloudiness')
plt.show()

# %% [markdown]
# # This plot graph on cloudiness displays once again how there isn't much of a relationship between latitude and cloudiness

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(lat,wspeed)
plt.title('Latitude vs. Wind Speed (4/25/2021)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.savefig('weather_images/latitude_vs_windspeed')
plt.show()

# %% [markdown]
# # This graph shows a small positive correlation between latitude and wind speed

# %% [markdown]
# ## Linear Regression

# %%
north_hemi = df.loc[df['Lat']>0]
south_hemi = df.loc[df['Lat']<0]
n_max_t = north_hemi.iloc[:,4]
n_lat = north_hemi.iloc[:,1]

# %%
def regression_plot(
    x_values, x_label, y_values, y_label,
    title, coords):
    plt.scatter(x_values,y_values,)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    vc_slope, vc_int, vc_r, vc_p, vc_std_err = linregress(x_values, y_values)    
    vc_fit = vc_slope * x_values + vc_int
    plt.plot(x_values,vc_fit,'--',color='r')
    plt.title(title)
    plt.annotate(f'Y = {round(vc_slope,2)}X + {round(vc_int,2)}',coords)
    
    
x_values = n_lat
x_label = 'Latitude'
y_values = n_max_t
y_label = 'Max Temp'
title = 'Northern Latitude vs. Max Temperature (4/26/21)'
coords = [5,15]

regression_plot(x_values, x_label, y_values, y_label,
    title, coords)

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = n_lat
x_label = 'Latitude'
y_values = n_max_t
y_label = 'Max Temp'
title = 'Northern Latitude vs. Max Temperature (4/26/21)'
coords = [5,15]

regression_plot(x_values, x_label, y_values, y_label,
    title, coords)

# %% [markdown]
# # This linear regression graph displays the negative relationship bweteen max temp and latitude from the northern hemisphere. Which makes sense since higher latitudes are closer to the north pole

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
s_maxt = south_hemi.iloc[:,4]
s_lat = south_hemi.iloc[:,1]

x_values = s_lat
x_label = 'Latitude'
y_values = s_maxt
y_label = 'Max Temp'
title = 'Southern Latitude vs. Max Temperature (4/26/21)'
coords = [-20,50]

regression_plot(x_values, x_label, y_values, y_label,
    title, coords)

# %% [markdown]
# # This linear regression model displays the positive correlation between latitude and max temp, as the latitude gets closer to the equator it gets hotter from the southern hemisphere. The pvalue here would suggest that this is insignificant, however.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
n_humid = north_hemi.iloc[:,9]

x_values = n_lat
x_label = 'Latitude'
y_values = n_humid
y_label = 'Max Temp'
title = 'Northern Latitude vs. Humidity (4/26/21)'
coords = [55,20]

regression_plot(x_values, x_label, y_values, y_label,
    title, coords)

# %% [markdown]
# # This linear regression model displays the small positive correlation between latitude and humidity from the northern hemisphere.The pvalue displays this regresssion model to be significant as well

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
s_humid = south_hemi.iloc[:,9]

x_values = s_lat
x_label = 'Latitude'
y_values = s_humid
y_label = 'Max Temp'
title = 'Southern Latitude vs. Humidity (4/26/21) '
coords = [-55,20]

regression_plot(x_values, x_label, y_values, y_label,
    title, coords)

# %% [markdown]
# # This linear regression model displays the positive relationship between humidity and latitude from the northern hemisphere. It would appear that the closer to the equator the more humid it's going to be. The pvalue displays this regresssion model to be significant as well

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
n_cloud = north_hemi.iloc[:,5]

x_values = n_lat
x_label = 'Latitude'
y_values = n_cloud
y_label = 'Max Temp'
title = 'Nothern Latitude vs. Cloudiness (4/26/21)'
coords = [50,30]

regression_plot(x_values, x_label, y_values, y_label,
    title, coords)

# %% [markdown]
# # Interestingly enough I stated prior that I did not believe there to be a relationship between latitude and cloudiness from the northern hemisphere. However, it would seem that there's a positive relationship here. The pvalue also displays this relationship to be significant as well

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
s_cloud = south_hemi.iloc[:,5]

x_values = s_lat
x_label = 'Latitude'
y_values = s_cloud
y_label = 'Cloudiness'
title = 'Southern Latitude vs. Cloudiness 4/26/21'
coords = [-55,15]

regression_plot(x_values, x_label, y_values, y_label,
    title, coords)

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# # This linear regression model displays the positive relationship between latitude and cloudiness, albeit a small one from the southern hemisphere. Interestingly enough I would have assumed that it would be less cloudy towards the equator with the higher max temp, but it would seem to be the opposite.

# %%
n_wspeed = north_hemi.iloc[:,6]

x_values = n_lat
x_label = 'Latitude'
y_values = n_wspeed
y_label = 'Wind Speed'
title = 'Nothern Latitude vs. Cloudiness (4/26/21)'
coords = [10,30]

regression_plot(x_values, x_label, y_values, y_label,
    title, coords)

# %% [markdown]
# # This linear regression model displays a very miniscule relationship between latitude and wind speed from the northern hemisphere. However the pvalue would suggest that this is significant

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
s_wspeed = south_hemi.iloc[:,6]
x_values = s_lat
x_label = 'Latitude'
y_values = s_wspeed
y_label = 'Wind Speed'
title = 'Southern Latitude vs. Cloudiness (4/26/21)'
coords = [-50,20]

regression_plot(x_values, x_label, y_values, y_label,
    title, coords)

# %% [markdown]
# # This linear regression model displays the significant negative relationship between latitude and wind speed from the southern hemisphere
