# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import csv

# Import API key
from api_keys import (weather_api_key,g_key)

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
import_csv = "../WeatherPy/city_data.csv"    
data_df = pd.read_csv(import_csv,encoding='utf-8')
data_df
# Out:
#      Unnamed: 0                     City      Lat       Lon   Temp  Max Temp  \
# 0             0                    Avera  33.1940  -82.5271  62.64     64.40
# 1             1  Gizo Government Station  -8.1030  156.8419  83.21     83.21
# 2             2               Bredasdorp -34.5322   20.0403  62.08     62.08
# 3             3                   Viedma -40.8135  -62.9967  60.58     60.58
# 4             4                Busselton -33.6500  115.3333  55.08     57.00
# ..          ...                      ...      ...       ...    ...       ...
# 552         552                   Aktobe  50.2797   57.2072  48.20     48.20
# 553         553                 Portland  45.5234 -122.6762  64.13     66.99
# 554         554                Orbetello  42.4408   11.2196  48.56     48.99
# 555         555                    Kiama -34.6833  150.8667  60.76     62.01
# 556         556               Ambon City  -3.6954  128.1814  78.80     78.80
#
#      Cloudiness  Wind Speed Country        Date  Humidity
# 0             1        9.22      US  1619131767        19
# 1           100        3.62      SB  1619132237        71
# 2             1        1.88      ZA  1619131697        92
# 3            40        7.14      AR  1619132036        59
# 4            82        1.99      AU  1619131934        84
# ..          ...         ...     ...         ...       ...
# 552           0        8.95      KZ  1619132228        49
# 553          75        3.58      US  1619132173        48
# 554          20        5.75      IT  1619132412        87
# 555           0       11.99      AU  1619132412        58
# 556          40        6.91      ID  1619132292        94
#
# [557 rows x 11 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)
marker_l = data_df[['Lat','Lon']].astype(float) 
fig = gmaps.figure(layout={
        'width': '500px',
        'height': '400px',
        'padding': '3px',
        'border': '1px solid black'
})
heatmap_layer = gmaps.heatmap_layer(marker_l, weights=data_df['Humidity'],max_intensity=900, point_radius=20.0
)
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='400px', padding='3px', width='500px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
hotel_df = data_df.loc[(data_df['Temp']<80) & (data_df['Temp']>70) & (data_df['Wind Speed']<10) & (data_df['Cloudiness'] ==0)] 
hotel_df = hotel_df.dropna()
hotel_df['Hotel'] = ""
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
for index,row in hotel_df.iterrows():
    lat = hotel_df['Lat']
    lon = hotel_df['Lon']
    params = {
    "location": "39.952583,-75.16522",  # philadelphia coords
    "rankby": "distance",
    "type": "hotel",
    "key": g_key,}
    response = requests.get(url,params=params).json()
    
response
# Out:
# {'html_attributions': [],
#  'next_page_token': 'ATtYBwItOqitR7c04OdSaik7ydtIs7zgoDZTpBl92hV8Mq87QGVJ1ixdfWfRwp0EOpK2ivScsW3ziTIQ2_ZEIDpZrN1XCxtS84W6at9NYUhO3B7XuP3Wlf0MdKDiIbZH5wA7a9fevm_vg8qRs_bqloQx7TdTHPVLXWwfXiRMvQ-HmOq4q-_1Y_BvAodfO7C201AH3McLAbStRos3IPWvopudUCe1zmr3Q494wCQbIlFrZdOjP7iMOsANXEGjYgi77w3SMvR5WYi3xjBCV71fufEJT0T3Wu7OoT-FZPJsY4R5CTuDI7JsyjO1CDywjHVOn8ovjkySGvgxsmvT8oB-_IZEa1vsJziKcwdBlMSjbDmb71Mjzwy8Z8XzlvfsuhPeclGMaj2AF7Aby2VRz1Oal5UbwAwyUnHQTYE7fr_RMLYbHzAFGqhxcAUkQb6D',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.9525839, 'lng': -75.1652215},
#     'viewport': {'northeast': {'lat': 39.9539650802915,
#       'lng': -75.1638658697085},
#      'southwest': {'lat': 39.9512671197085, 'lng': -75.16656383029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'AFRO ALPACA BIJOUX',
#    'place_id': 'ChIJu4BtOi7GxokRShd5wVR3SgY',
#    'reference': 'ChIJu4BtOi7GxokRShd5wVR3SgY',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'store', 'establishment'],
#    'vicinity': 'Stillwater Estate, Rondeberg Road, Philadelphia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.9525839, 'lng': -75.1652215},
#     'viewport': {'northeast': {'lat': 39.9539650802915,
#       'lng': -75.1638658697085},
#      'southwest': {'lat': 39.9512671197085, 'lng': -75.16656383029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Phat Girl Lashes',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJ7d63s27HxokRMJmPN7xGQXM',
#    'plus_code': {'compound_code': 'XR3M+2W Philadelphia, PA, USA',
#     'global_code': '87F6XR3M+2W'},
#    'reference': 'ChIJ7d63s27HxokRMJmPN7xGQXM',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'vicinity': '1820 Love World, Philadelphia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.9525839, 'lng': -75.1652215},
#     'viewport': {'northeast': {'lat': 39.9539650802915,
#       'lng': -75.1638658697085},
#      'southwest': {'lat': 39.9512671197085, 'lng': -75.16656383029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Stone Cooper',
#    'place_id': 'ChIJKfR43t3HxokRTn_Wz0dWQ5Q',
#    'plus_code': {'compound_code': 'XR3M+2W Philadelphia, PA, USA',
#     'global_code': '87F6XR3M+2W'},
#    'rating': 5,
#    'reference': 'ChIJKfR43t3HxokRTn_Wz0dWQ5Q',
#    'scope': 'GOOGLE',
#    'types': ['jewelry_store', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Philadelphia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.9525839, 'lng': -75.1652215},
#     'viewport': {'northeast': {'lat': 39.9539650802915,
#       'lng': -75.1638658697085},
#      'southwest': {'lat': 39.9512671197085, 'lng': -75.16656383029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Top App Developer: iOS and Android. Mobile and Web applications',
#    'photos': [{'height': 9248,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115560804463299395264">SYNERGY Consulting</a>'],
#      'photo_reference': 'ATtYBwLJo7AoQgqeRZdgvxD48Mi9qcWH1wnaphIuhrKXGnzKy-R4k0sGIyDM3ECDrEkSYPLBfx2aCg2IKZ3T9s1dZNn4b3Or1DYSG2PLt9Z482VibjMjg82gT6QPZtQHMY4gDkZRjaEcSx_ma8KCUjUDIxUQ1YophjxqxOYXEHBHcnNXTMQa',
#      'width': 6936}],
#    'place_id': 'ChIJic1TGSnHxokRkegsXmRMg4w',
#    'plus_code': {'compound_code': 'XR3M+2W Philadelphia, PA, USA',
#     'global_code': '87F6XR3M+2W'},
#    'rating': 5,
#    'reference': 'ChIJic1TGSnHxokRkegsXmRMg4w',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Philadelphia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.9525839, 'lng': -75.1652215},
#     'viewport': {'northeast': {'lat': 39.9539650802915,
#       'lng': -75.1638658697085},
#      'southwest': {'lat': 39.9512671197085, 'lng': -75.16656383029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_general-71.png',
#    'name': 'St ambrose catholic church',
#    'place_id': 'ChIJSfmTHjPHxokRqe3yP7qCwsk',
#    'plus_code': {'compound_code': 'XR3M+2W Philadelphia, PA, USA',
#     'global_code': '87F6XR3M+2W'},
#    'reference': 'ChIJSfmTHjPHxokRqe3yP7qCwsk',
#    'scope': 'GOOGLE',
#    'types': ['church',
#     'place_of_worship',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': 'Philadelphia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.9525839, 'lng': -75.1652215},
#     'viewport': {'northeast': {'lat': 39.9539650802915,
#       'lng': -75.1638658697085},
#      'southwest': {'lat': 39.9512671197085, 'lng': -75.16656383029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Orthopedic Institute in Philadelphia',
#    'place_id': 'ChIJJ87HtHzHxokRqnYgQIj6cC4',
#    'plus_code': {'compound_code': 'XR3M+2W Philadelphia, PA, USA',
#     'global_code': '87F6XR3M+2W'},
#    'reference': 'ChIJJ87HtHzHxokRqnYgQIj6cC4',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'vicinity': 'Philadelphia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.9525839, 'lng': -75.1652215},
#     'viewport': {'northeast': {'lat': 39.9539650802915,
#       'lng': -75.1638658697085},
#      'southwest': {'lat': 39.9512671197085, 'lng': -75.16656383029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Tommy hilfilger',
#    'place_id': 'ChIJgdbAphrHxokRzqxPIleQ3aI',
#    'plus_code': {'compound_code': 'XR3M+2W Philadelphia, PA, USA',
#     'global_code': '87F6XR3M+2W'},
#    'reference': 'ChIJgdbAphrHxokRzqxPIleQ3aI',
#    'scope': 'GOOGLE',
#    'types': ['shopping_mall', 'point_of_interest', 'establishment'],
#    'vicinity': 'Philadelphia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.9525839, 'lng': -75.1652215},
#     'viewport': {'northeast': {'lat': 39.9539650802915,
#       'lng': -75.1638658697085},
#      'southwest': {'lat': 39.9512671197085, 'lng': -75.16656383029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'CliqueCam',
#    'place_id': 'ChIJQfYp5U3HxokRpM_LicW97wM',
#    'plus_code': {'compound_code': 'XR3M+2W Philadelphia, PA, USA',
#     'global_code': '87F6XR3M+2W'},
#    'reference': 'ChIJQfYp5U3HxokRpM_LicW97wM',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'vicinity': 'Philadelphia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.9525839, 'lng': -75.1652215},
#     'viewport': {'northeast': {'lat': 39.9539650802915,
#       'lng': -75.1638658697085},
#      'southwest': {'lat': 39.9512671197085, 'lng': -75.16656383029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Warehouse',
#    'place_id': 'ChIJVSTuCePHxokRd028iVjDKUQ',
#    'plus_code': {'compound_code': 'XR3M+2W Philadelphia, PA, USA',
#     'global_code': '87F6XR3M+2W'},
#    'reference': 'ChIJVSTuCePHxokRd028iVjDKUQ',
#    'scope': 'GOOGLE',
#    'types': ['home_goods_store',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'vicinity': 'Warehouse/Shopper Team Member, Philadelphia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.9525839, 'lng': -75.1652215},
#     'viewport': {'northeast': {'lat': 39.9539650802915,
#       'lng': -75.1638658697085},
#      'southwest': {'lat': 39.9512671197085, 'lng': -75.16656383029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Ki zel',
#    'place_id': 'ChIJV4cm6-nHxokRF9Cp8OncMYo',
#    'plus_code': {'compound_code': 'XR3M+2W Philadelphia, PA, USA',
#     'global_code': '87F6XR3M+2W'},
#    'reference': 'ChIJV4cm6-nHxokRF9Cp8OncMYo',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Philadelphia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.9525839, 'lng': -75.1652215},
#     'viewport': {'northeast': {'lat': 39.9539650802915,
#       'lng': -75.1638658697085},
#      'southwest': {'lat': 39.9512671197085, 'lng': -75.16656383029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Phialadephia Navy Shipyard',
#    'place_id': 'ChIJ67NqinDHxokRG_6_jYluZf8',
#    'plus_code': {'compound_code': 'XR3M+2W Philadelphia, PA, USA',
#     'global_code': '87F6XR3M+2W'},
#    'reference': 'ChIJ67NqinDHxokRG_6_jYluZf8',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'vicinity': 'Navy Shipyard, Philadelphia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.9525839, 'lng': -75.1652215},
#     'viewport': {'northeast': {'lat': 39.9539650802915,
#       'lng': -75.1638658697085},
#      'southwest': {'lat': 39.9512671197085, 'lng': -75.16656383029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Mystic, Connecticut',
#    'place_id': 'ChIJEYwQplDHxokR0grjr208P-E',
#    'plus_code': {'compound_code': 'XR3M+2W Philadelphia, PA, USA',
#     'global_code': '87F6XR3M+2W'},
#    'reference': 'ChIJEYwQplDHxokR0grjr208P-E',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '1501 Market Street, Philadelphia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.9525839, 'lng': -75.1652215},
#     'viewport': {'northeast': {'lat': 39.9539650802915,
#       'lng': -75.1638658697085},
#      'southwest': {'lat': 39.9512671197085, 'lng': -75.16656383029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_general-71.png',
#    'name': 'Highpointe Church',
#    'place_id': 'ChIJ3Qbb_WzHxokRiFZ5-RiG6pg',
#    'plus_code': {'compound_code': 'XR3M+2W Philadelphia, PA, USA',
#     'global_code': '87F6XR3M+2W'},
#    'reference': 'ChIJ3Qbb_WzHxokRiFZ5-RiG6pg',
#    'scope': 'GOOGLE',
#    'types': ['church',
#     'place_of_worship',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': 'Philadelphia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.9525839, 'lng': -75.1652215},
#     'viewport': {'northeast': {'lat': 39.9539650802915,
#       'lng': -75.1638658697085},
#      'southwest': {'lat': 39.9512671197085, 'lng': -75.16656383029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'name': 'Visa Boba Tea',
#    'place_id': 'ChIJuWy5po3HxokReXo2yLQPaWI',
#    'plus_code': {'compound_code': 'XR3M+2W Philadelphia, PA, USA',
#     'global_code': '87F6XR3M+2W'},
#    'rating': 5,
#    'reference': 'ChIJuWy5po3HxokReXo2yLQPaWI',
#    'scope': 'GOOGLE',
#    'types': ['cafe', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Philadelphia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.9525839, 'lng': -75.1652215},
#     'viewport': {'northeast': {'lat': 39.9539650802915,
#       'lng': -75.1638658697085},
#      'southwest': {'lat': 39.9512671197085, 'lng': -75.16656383029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'The Musical Fund Society',
#    'place_id': 'ChIJu4BtOi7GxokREYcwt1Gx68c',
#    'plus_code': {'compound_code': 'XR3M+2W Philadelphia, PA, USA',
#     'global_code': '87F6XR3M+2W'},
#    'reference': 'ChIJu4BtOi7GxokREYcwt1Gx68c',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'vicinity': 'Philadelphia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.9525839, 'lng': -75.1652215},
#     'viewport': {'northeast': {'lat': 39.9539650802915,
#       'lng': -75.1638658697085},
#      'southwest': {'lat': 39.9512671197085, 'lng': -75.16656383029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#    'name': 'Allison Eibel',
#    'place_id': 'ChIJ2Xpj9ffHxokRecktszC7e9Q',
#    'plus_code': {'compound_code': 'XR3M+2W Philadelphia, PA, USA',
#     'global_code': '87F6XR3M+2W'},
#    'reference': 'ChIJ2Xpj9ffHxokRecktszC7e9Q',
#    'scope': 'GOOGLE',
#    'types': ['school', 'point_of_interest', 'establishment'],
#    'vicinity': 'Philadelphia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.9525839, 'lng': -75.1652215},
#     'viewport': {'northeast': {'lat': 39.9539650802915,
#       'lng': -75.1638658697085},
#      'southwest': {'lat': 39.9512671197085, 'lng': -75.16656383029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Janis Jean & Co.',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105749841239305920759">Janis Jean &amp; Co.</a>'],
#      'photo_reference': 'ATtYBwIxCLISA-LzUeRxZalpfWpk_9PoGzNENcM1Sk_4xPtUhr0KYsKrraczey_L3VRmfbf1IEbjD-c5KvRiA_l9v-vorxDkK53hYPie8lqvYvdB61kna5-hH-FnbixWZjVWdjNCrWdnKza0J3Cpw9KKDvg9SmD5OSRzTwiBPwA3yvAh48MK',
#      'width': 1080}],
#    'place_id': 'ChIJC5EC0BfJxokRW6YV4Vy6YXo',
#    'plus_code': {'compound_code': 'XR3M+2W Philadelphia, PA, USA',
#     'global_code': '87F6XR3M+2W'},
#    'rating': 5,
#    'reference': 'ChIJC5EC0BfJxokRW6YV4Vy6YXo',
#    'scope': 'GOOGLE',
#    'types': ['clothing_store', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 11,
#    'vicinity': 'Philadelphia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.9525839, 'lng': -75.1652215},
#     'viewport': {'northeast': {'lat': 39.9539650802915,
#       'lng': -75.1638658697085},
#      'southwest': {'lat': 39.9512671197085, 'lng': -75.16656383029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_general-71.png',
#    'name': 'Enon Tabernacle Baptist Church',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJ33OneiXHxokRILt-At3AD5w',
#    'plus_code': {'compound_code': 'XR3M+2W Philadelphia, PA, USA',
#     'global_code': '87F6XR3M+2W'},
#    'reference': 'ChIJ33OneiXHxokRILt-At3AD5w',
#    'scope': 'GOOGLE',
#    'types': ['church',
#     'place_of_worship',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': 'Philadelphia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.9525839, 'lng': -75.1652215},
#     'viewport': {'northeast': {'lat': 39.9539650802915,
#       'lng': -75.1638658697085},
#      'southwest': {'lat': 39.9512671197085, 'lng': -75.16656383029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Philadelphia Mailroom',
#    'place_id': 'ChIJj8bBi6fHxokR-nxgdsJe8Ow',
#    'plus_code': {'compound_code': 'XR3M+2W Philadelphia, PA, USA',
#     'global_code': '87F6XR3M+2W'},
#    'reference': 'ChIJj8bBi6fHxokR-nxgdsJe8Ow',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'vicinity': 'Philadelphia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.9525839, 'lng': -75.1652215},
#     'viewport': {'northeast': {'lat': 39.9539650802915,
#       'lng': -75.1638658697085},
#      'southwest': {'lat': 39.9512671197085, 'lng': -75.16656383029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hoilday Inn',
#    'place_id': 'ChIJu4BtOi7GxokRec0ZAlI_b7k',
#    'plus_code': {'compound_code': 'XR3M+2W Philadelphia, PA, USA',
#     'global_code': '87F6XR3M+2W'},
#    'reference': 'ChIJu4BtOi7GxokRec0ZAlI_b7k',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Philadelphia'}],
#  'status': 'OK'}

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-464b2b3e63ad> in <module>
#      11 # Store the DataFrame Row
#      12 # NOTE: be sure to update with your DataFrame name
# ---> 13 hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
#      14 locations = hotel_df[["Lat", "Lng"]]
#
# <ipython-input-5-464b2b3e63ad> in <listcomp>(.0)
#      11 # Store the DataFrame Row
#      12 # NOTE: be sure to update with your DataFrame name
# ---> 13 hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
#      14 locations = hotel_df[["Lat", "Lng"]]
#
# KeyError: 'Hotel Name'

# %%
# Add marker layer ontop of heat map


# Display figure
